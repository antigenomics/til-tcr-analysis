# %%
from collections import defaultdict
gened = defaultdict(list)
specied = defaultdict(list)
specied2 = {}
import numpy as np
import pandas as pd

with open("annot.summary.txt") as f:
    for line in f.readlines():
        l = line.split("\t")
        if l[0] != "sample_id":
            idx = l[0]
            resp = l[1]
            species = l[6].strip()
            if species.isdigit() == False:
                specied[idx].append(species)
        
        
        
for key, val in specied.items():
    s = ""
    for el in val:
        s += el+","
    s1 = s.strip(",")
    specied2[key] = s1
    #print (s1)
 

pd.DataFrame(list(specied2.items()),
                      columns=['Allen_Sample_id','Species_antigen'])
# Out:
#    Allen_Sample_id                                    Species_antigen
# 0       SRR2775133                                                HCV
# 1       SRR2780299                          HIV-1,EBV,EBV,HomoSapiens
# 2       SRR2751521                                      HIV-1,CMV,HCV
# 3       SRR2778361  HIV-1,HCV,HIV-1,HIV-1,CMV,HIV-1,HCV,HCV,HomoSa...
# 4       SRR2669446                                                EBV
# 5       SRR2772780                                      EBV,CMV,HIV-1
# 6       SRR2689710                    CMV,HIV-1,EBV,EBV,EBV,HIV-1,HCV
# 7       SRR2774182                                        EBV,EBV,HCV
# 8       SRR2675767                        HCV,HomoSapiens,HomoSapiens
# 9       SRR2674135  CMV,EBV,HIV-1,HSV-2,EBV,CMV,EBV,EBV,HCV,HIV-1,...
# 10      SRR2757338  HCV,HIV-1,EBV,HomoSapiens,EBV,CMV,EBV,EBV,HIV-...
# 11      SRR2778056                              HIV-1,CMV,EBV,CMV,HCV
# 12      SRR2779596                                                HCV
# 13      SRR2755094                                              HIV-1
# 14      SRR2777976                                          HIV-1,CMV
# 15      SRR2660032  HCV,HIV-1,CMV,HSV-2,HIV-1,CMV,EBV,HomoSapiens,...
# 16      SRR2771286                          HCV,HIV-1,EBV,EBV,EBV,HCV
# 17      SRR2770872                                    EBV,CMV,EBV,HCV
# 18      SRR2778078  HIV-1,CMV,EBV,HCV,CMV,HIV-1,EBV,EBV,CMV,EBV,EB...
# 19      SRR2771207                                        CMV,EBV,HCV
# 20      SRR2779183  CMV,HCV,HIV-1,HSV-2,EBV,EBV,HCV,HIV-1,CMV,EBV,...
# 21      SRR2681702  CMV,HIV-1,CMV,EBV,HCV,EBV,HIV-1,HomoSapiens,EB...
# 22      SRR2753064                                          HIV-1,CMV
# 23      SRR2778466                                              HIV-1
# 24      SRR2701663  HCV,HIV-1,EBV,HomoSapiens,EBV,CMV,HomoSapiens,...
# 25      SRR2780275    HCV,HomoSapiens,HIV-1,EBV,HomoSapiens,HCV,HIV-1
# 26      SRR2778609        HCV,HIV-1,HIV-1,EBV,CMV,CMV,EBV,CMV,HCV,HCV
# 27      SRR3083781                     HIV-1,EBV,CMV,TriticumAestivum
# 28      SRR2771617                                          EBV,HIV-1
# 29      SRR2774280  HomoSapiens,HIV-1,EBV,CMV,HIV-1,CMV,EBV,HomoSa...
# 30      SRR2712420  HCV,CMV,HIV-1,HIV-1,HIV-1,HIV-1,CMV,CMV,EBV,EB...
